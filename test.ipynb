# %%
import numpy as np
from classes import linear_regression as lr

# %%
X = np.random.randint(0,5,10)
y = np.random.randint(0,5,10)

model = lr.LinearRegression()
model.fit(X,y)
model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 y = np.random.randint(0,5)
#       4 model = lr.LinearRegression()
# ----> 5 model.fit(X,y)
#       6 model.predict(X)
#
# File c:\Users\joelc\Desktop\MachineLearningScratch\classes\linear_regression.py:37, in LinearRegression.fit(self, X, Y)
#      34     X=X.reshape(-1,1)
#      35 Y = Y.reshape(-1,1)
# ---> 37 n_observations = X.shape[0]
#      38 # Design matrix with a column of 1s, and each other column is the respective feature column
#      39 X_design = np.hstack((np.ones((n_observations,1)),X))
#
# IndexError: tuple index out of range
